# %% [markdown]
# # NMD score tables pre-processing

# %%
import pandas as pd
import re
from tqdm.notebook import tqdm
from operator import add

# %% [markdown]
# ## Prepare input nmd_scores table

# %%
#Import the table with NMD scores

nmdA_df = pd.read_table("/workspace/users/msanchezg/notebooks/protein_degradation/NMDetective/nmd.scores.A.tsv.gz", sep='\t')
nmdA_df['alignID.1'] = nmdA_df['transcript_id'].str.split('.',expand=True)[0]
nmdA_df['alignID.1'] = nmdA_df['alignID.1'].str.split(' ',expand=True)[1]
nmdA_df
# Out:
# /home/msanchezg/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (5,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        CHROM Feature     Start       End Strand Frame     gene_id  \
# 0       chr1     CDS     69091     70005      +     0  uc001aal.1
# 1       chr1     CDS    182709    182746      +     0  uc057auo.1
# 2       chr1     CDS    183114    183240      +     1  uc057auo.1
# 3       chr1     CDS    183922    184155      +     0  uc057auo.1
# 4       chr1     CDS    185220    185350      -     2  uc057aup.1
# ...      ...     ...       ...       ...    ...   ...         ...
# 702477  chrY     CDS  57190204  57190375      +     1  uc004fxm.2
# 702478  chrY     CDS  57190969  57191085      +     0  uc004fxm.2
# 702479  chrY     CDS  57191798  57191999      +     0  uc004fxm.2
# ...

# %%
#Import table with UCSC / ENS annotation (UCSC table browser)

annot_df = pd.read_table("/workspace/users/msanchezg/notebooks/protein_degradation/NMDetective/annotation.ucsc.ens.tsv.gz", sep="\t")
annot_df['alignID.1'] = annot_df['alignID'].str.split('.',expand=True)[0]
annot_df['Transcript_ens'] = annot_df['#name'].str.split('.',expand=True)[0]
annot_df = annot_df[['Transcript_ens','alignID.1','exonCount']]
annot_df.drop_duplicates(inplace=True, keep='first')
annot_df
# Out:
#          Transcript_ens alignID.1  exonCount
# 0       ENST00000456328  uc286dmu          3
# 1       ENST00000450305  uc286dmv          6
# 2       ENST00000488147  uc286dmw         11
# 3       ENST00000619216  uc031tla          1
# 4       ENST00000473358  uc057aty          3
# ...                 ...       ...        ...
# 247536  ENST00000615362  uc286tlf          2
# 247537  ENST00000617983  uc062frj          1
# 247538  ENST00000613204  uc032quk          5
# 247539  ENST00000615165  uc032qun         14
# 247540  ENST00000621424  uc032qum         15
#
# [247380 rows x 3 columns]

# %%
#Merge tables

nmdA_annot_df = pd.merge(nmdA_df,annot_df, how='left')
nmdA_annot_df = nmdA_annot_df[['CHROM','Start','End','Strand','Frame','exon_number','exonCount','Transcript_ens','nmd_score']][~nmdA_annot_df['Transcript_ens'].isnull()]
nmdA_annot_df
# Out:
#        CHROM     Start       End Strand Frame exon_number  exonCount  \
# 0       chr1     69091     70005      +     0           1        3.0
# 40      chr1    450743    451678      -     0           1        1.0
# 41      chr1    685719    686654      -     0           1        1.0
# 42      chr1    925942    926013      +     0           2        7.0
# 43      chr1    930155    930336      +     0           3        7.0
# ...      ...       ...       ...    ...   ...         ...        ...
# 702477  chrY  57190204  57190375      +     1           5        9.0
# 702478  chrY  57190969  57191085      +     0           6        9.0
# 702479  chrY  57191798  57191999      +     0           7        9.0
# 702480  chrY  57192603  57192708      +     2           8        9.0
# 702481  chrY  57196336  57196369      +     1           9        9.0
#
#          Transcript_ens                                          nmd_score
# ...

# %%
#Save table for posterior analysis with pyhton/qmap script

nmdA_annot_df.to_csv(r'nmdA.annot.enst.tsv', header=True, index=None, sep='\t')

# %% [markdown]
# ## Transcript ID of genes with ns and fs

# %%
#Load CPTAC dataset

CPTAC = ['BRCA', 'CCRCC', 'COAD', 'GBM', 'LUAD', 'OV', 'UCEC']
cptac_df = pd.DataFrame(columns=['gene', 'cpct_aliquot', 'protein_expression', 'aliquot', 'sample',
       'Type', 'median', 'stdev', 'norm_protein_expression', 'log2fpkm',
       'log10fpkm', '#Uploaded_variation', 'Location', 'Allele', 'Feature',
       'protein_mutation', 'Protein_position', 'Amino_acids', 'Consequence',
       'Phenotype', 'Ubiquitinases_Mutated', 'Altered_E3_Ligases',
       'Raw_Residual', 'Stability_Change', 'ABS_Stability_Change'])
for cancer in tqdm(CPTAC, total=len(CPTAC),desc='Load CPTAC data'):
    df = pd.read_csv("/workspace/projects/cptac_analysis/data/"+cancer+"/dataset_irls.gz", sep='\t')
    Dataset = [cancer] * len(df)
    df['Dataset'] = Dataset
    frames = [cptac_df, df]
    cptac_df = pd.concat(frames)
cptac_df.drop_duplicates(keep='first',inplace=True)

# %%
#Load CCLE dataset

ccle_df = pd.read_csv("/workspace/projects/cptac_analysis/data/CCLE/dataset_irls.gz", sep='\t')

# %%
genes_ns_fs_cptac_df = cptac_df[['Feature']][(cptac_df['Phenotype']=='stop_gained')|(cptac_df['Phenotype']=='frameshift_variant')]
genes_ns_fs_ccle_df = ccle_df[['Feature']][(ccle_df['Phenotype']=='stop_gained')|(ccle_df['Phenotype']=='frameshift_variant')]

genes_ns_fs_df = pd.concat([genes_ns_fs_cptac_df, genes_ns_fs_ccle_df], ignore_index=True)
genes_ns_fs_df.drop_duplicates(inplace=True,keep='first',ignore_index=True)

# %%
genes_ns_fs_df
# Out:
#               Feature
# 0     ENST00000645829
# 1     ENST00000645237
# 2     ENST00000376142
# 3     ENST00000616317
# 4     ENST00000642319
# ...               ...
# 8391  ENST00000376670
# 8392  ENST00000345034
# 8393  ENST00000273371
# 8394  ENST00000378076
# 8395  ENST00000222598
#
# [8396 rows x 1 columns]

# %%
genes_ns_fs_df.to_csv(r'genes_ns_fs.tsv', header=True, index=None, sep='\t')
